# %%
#Goal:
#Produce a cleaned CSV in data/clean/ that can be fed to train.py.
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/train.csv")

# %%
#Drop columns (sparse / noise)
drop_cols = [
    "Id", "PoolQC", "MiscFeature", "Alley", "Fence",
    "GarageArea", "BsmtFinSF1", "BsmtUnfSF", "GarageYrBlt",
    "TotRmsAbvGrd", "MoSold", "YrSold", "MiscVal", "1stFlrSF"
]
df.drop(columns=drop_cols, inplace=True)

# %%
# Convert numeric → categorical
df["MSSubClass"] = df["MSSubClass"].astype("object")

# %%
# Fill "None" for categorical columns
fill_none_cols = [
    "FireplaceQu", "GarageType", "GarageFinish", "GarageQual", "GarageCond",
    "BsmtQual", "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2",
    "MasVnrType"
]
df[fill_none_cols] = df[fill_none_cols].fillna("None")

# Median for numeric columns with outliers
median_cols = ["LotFrontage", "MasVnrArea"]
for col in median_cols:
    df[col] = df[col].fillna(df[col].median())  # assign back

# Mode for small missing
df["Electrical"] = df["Electrical"].fillna(df["Electrical"].mode()[0])

# %%
# Optional: cap extreme numeric outliers
df["LotFrontage"] = df["LotFrontage"].clip(upper=df["LotFrontage"].quantile(0.99))

# Optional: log-transform target (can do later after train-test split)
# df["SalePrice_log"] = np.log1p(df["SalePrice"])

# %%
# Save cleaned data
df.to_csv("../data/clean/train_clean.csv", index=False)

# %%
print("Data cleaning done. Clean CSV saved at data/clean/train_clean.csv")
# Out:
# Data cleaning done. Clean CSV saved at data/clean/train_clean.csv
